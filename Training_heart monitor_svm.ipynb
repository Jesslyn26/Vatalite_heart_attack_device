# %% [markdown]
# Import libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from scipy.stats import boxcox
from scipy import stats
from sklearn.preprocessing import  MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from sklearn.metrics import  precision_score, recall_score, f1_score, average_precision_score, precision_recall_curve, roc_auc_score, accuracy_score
import joblib

# %% [markdown]
# Load dataset and concantinate dataset as one csv file

# %%
# Specify the folder containing the CSV files
folder_path = 'bidmc_csv'

# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Initialize an empty DataFrame to store the concatenated data
concatenated_data = pd.DataFrame()

# Iterate over the CSV files and concatenate them
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    data = pd.read_csv(file_path)
    concatenated_data = pd.concat([concatenated_data, data])

# Save the concatenated data to a new CSV file
concatenated_data.to_csv('concatenated_dataset.csv', index=False)

# %% [markdown]
# Data visualization

# %%
dataset = pd.read_csv('concatenated_dataset.csv')

print(dataset.describe())

pd.set_option("display.max.columns", None)
dataset.head()
# Out:
#            Time [s]            HR         PULSE          RESP          SpO2
# count  24531.000000  24527.000000  24403.000000  24378.000000  24403.000000
# mean     239.980392     89.253190     88.584723     17.401674     96.613162
# std      138.855339     13.517618     14.014707      3.460588      3.317676
# min       -1.000000     44.000000     37.000000      0.000000     83.000000
# 25%      120.000000     81.000000     80.000000     16.000000     95.000000
# 50%      240.000000     89.000000     88.000000     18.000000     97.000000
# 75%      360.000000     95.000000     95.000000     19.000000     99.000000
# max      480.000000    139.000000    129.000000     34.000000    100.000000
#    Time [s]    HR   PULSE   RESP   SpO2
# 0         0  94.0    93.0   25.0   97.0
# 1         1  94.0    93.0   25.0   97.0
# 2         2  94.0    93.0   25.0   97.0
# 3         3  92.0    93.0   26.0   97.0
# 4         4  93.0    93.0   26.0   97.0

# %% [markdown]
# Evaluating dataset

# %%
# Histogram graph
plt.title('Data distribution in "SPO2" data') 
x = dataset[' SpO2']
plt.hist(x)
plt.show() 

plt.title('Data distribution in "PULSE" data') 
x = dataset[' PULSE']
plt.hist(x)
plt.show()

# %% [markdown]
# Removing noises

# %%
column_to_delete = ['Time [s]', ' HR', ' RESP']

dataset = dataset.drop(column_to_delete, axis=1)

# Display the modified DataFrame
print("\nModified DataFrame:")
print(dataset)
# Out:
# Modified DataFrame:
#         PULSE   SpO2
# 0        93.0   97.0
# 1        93.0   97.0
# 2        93.0   97.0
# 3        93.0   97.0
# 4        93.0   97.0
# ...       ...    ...
# 24526   116.0   93.0
# 24527   116.0   93.0
# 24528   117.0   93.0
# 24529   117.0   93.0
# 24530   117.0   93.0
#
# [24531 rows x 2 columns]

# %% [markdown]
# Remove NA values

# %%
missing_values = dataset.isna()

# Count the missing values in each column
missing_counts = missing_values.sum()

# Print the columns with missing values
print("Columns with missing values:")
print(missing_values.iloc[3:])
# Out:
# Columns with missing values:
#         PULSE   SpO2
# 3       False  False
# 4       False  False
# 5       False  False
# 6       False  False
# 7       False  False
# ...       ...    ...
# 24526   False  False
# 24527   False  False
# 24528   False  False
# 24529   False  False
# 24530   False  False
#
# [24528 rows x 2 columns]

# %%
# Remove columns with missing values
clean_data = dataset.dropna()

# Print the cleaned DataFrame
print(clean_data)
# Out:
#         PULSE   SpO2
# 0        93.0   97.0
# 1        93.0   97.0
# 2        93.0   97.0
# 3        93.0   97.0
# 4        93.0   97.0
# ...       ...    ...
# 24526   116.0   93.0
# 24527   116.0   93.0
# 24528   117.0   93.0
# 24529   117.0   93.0
# 24530   117.0   93.0
#
# [24403 rows x 2 columns]

# %% [markdown]
# Removing duplication

# %%
df_unique = clean_data.drop_duplicates()

'''print("Original DataFrame:")
print(clean_data)'''

print("\nDataFrame with duplicates removed:")
print(df_unique)
# Out:
# DataFrame with duplicates removed:
#         PULSE   SpO2
# 0        93.0   97.0
# 6        94.0   97.0
# 26       94.0   98.0
# 44       92.0   97.0
# 61       91.0   97.0
# ...       ...    ...
# 24408   116.0   94.0
# 24410   117.0   94.0
# 24415   117.0   95.0
# 24416   116.0   95.0
# 24469   117.0   93.0
#
# [491 rows x 2 columns]

# %%
#Box plot to show the numeric value difference between oxygen level and heart rate
plt.title('Data outliers present in Spo2 and Pulse') 

boxplot = dataset.boxplot()

# Show the plot
plt.show()

# %% [markdown]
# Removing outliers

# %%
z_scores = np.abs(stats.zscore(df_unique[" PULSE"]))

# Define a threshold for outlier detection
threshold = 3

# Identify outlier indices
outlier_indices = np.where(z_scores > threshold)

# Remove outliers from the data
pulse_no_outliers = df_unique[np.logical_not(np.isin(np.arange(len(df_unique[" PULSE"])), outlier_indices))]

z_scores = np.abs(stats.zscore(pulse_no_outliers[" SpO2"]))

# Define a threshold for outlier detection
threshold = 3

# Identify outlier indices
outlier_indices = np.where(z_scores > threshold)

# Remove outliers from the data
data_no_outliers = pulse_no_outliers[np.logical_not(np.isin(np.arange(len(pulse_no_outliers[" SpO2"])), outlier_indices))]

# Print the original data and data without outliers
print("Data without Outliers:", data_no_outliers)
# Out:
# Data without Outliers:         PULSE   SpO2
# 0        93.0   97.0
# 6        94.0   97.0
# 26       94.0   98.0
# 44       92.0   97.0
# 61       91.0   97.0
# ...       ...    ...
# 24408   116.0   94.0
# 24410   117.0   94.0
# 24415   117.0   95.0
# 24416   116.0   95.0
# 24469   117.0   93.0
#
# [483 rows x 2 columns]

# %%
# Histogram graph
plt.title('Removed outliers in "PULSE" data') 
x = data_no_outliers[' PULSE']
plt.hist(x)
plt.show() 

plt.title('Removed outliers in "SpO2" data') 
x = data_no_outliers[' SpO2']
plt.hist(x)
plt.show()

# %% [markdown]
# Adding "healthy heart" as a target column based on pulse rate

# %%
# Add a new column named "target" using the function


clean_data[' HEALTHY HEART'] = 0

for index, row in clean_data.iterrows():    
    if row[' PULSE'] < 100 and row[' PULSE'] > 50:
        if row[' SpO2'] > 90:
            print(row[' PULSE'], row[' SpO2'])
            print("Heart healthy")
            clean_data.at[index, ' HEALTHY HEART'] = 1

        else: 
            clean_data.at[index, ' HEALTHY HEART'] = 0
    else:
        clean_data.at[index, ' HEALTHY HEART'] = 0
        print(row[' PULSE'])
        print("Heart unhealthy")
        


# Display the updated DataFrame
print(clean_data)
clean_data.to_csv('Training_heart.csv', index=False)
# Out:
# C:\Users\jessl\AppData\Local\Temp\ipykernel_22300\131199445.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data[' HEALTHY HEART'] = 0
# 93.0 97.0
# Heart healthy
# 93.0 97.0
# Heart healthy
# 93.0 97.0
# Heart healthy
# 93.0 97.0
# Heart healthy
# 93.0 97.0
# Heart healthy
# 93.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 98.0
# Heart healthy
# 94.0 98.0
# Heart healthy
# 94.0 98.0
# Heart healthy
# 94.0 98.0
# Heart healthy
# 94.0 98.0
# Heart healthy
# 94.0 98.0
# Heart healthy
# 94.0 98.0
# Heart healthy
# 94.0 98.0
# Heart healthy
# 94.0 98.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 94.0 97.0
# Heart healthy
# 93.0 97.0
# Heart healthy
# 93.0 97.0
# Heart healthy
# 93.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 92.0 96.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 91.0 96.0
# Heart healthy
# 92.0 96.0
# Heart healthy
# 92.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 96.0
# Heart healthy
# 90.0 96.0
# Heart healthy
# 90.0 96.0
# Heart healthy
# 90.0 96.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 89.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 91.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 97.0
# Heart healthy
# 90.0 96.0
# Heart healthy
# 90.0 96.0
# Heart healthy
# 90.0 96.0
# Heart healthy
# 90.0 96.0
# Heart healthy
# 90.0 96.0
# Heart healthy
# 90.0 96.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 87.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 88.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 90.0 99.0
# Heart healthy
# 90.0 99.0
# Heart healthy
# 90.0 99.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 95.0 100.0
# Heart healthy
# 95.0 100.0
# Heart healthy
# 95.0 100.0
# Heart healthy
# 95.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 89.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 94.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 93.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 92.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 91.0 100.0
# Heart healthy
# 90.0 100.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 78.0 96.0
# Heart healthy
# 78.0 96.0
# Heart healthy
# 78.0 96.0
# Heart healthy
# 78.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 75.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 76.0 97.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 77.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 96.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 77.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 76.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 95.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 75.0 96.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 96.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 94.0
# Heart healthy
# 94.0 94.0
# Heart healthy
# 94.0 94.0
# Heart healthy
# 94.0 94.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 95.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 94.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 93.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 92.0 93.0
# Heart healthy
# 91.0 92.0
# Heart healthy
# 91.0 92.0
# Heart healthy
# 92.0 92.0
# Heart healthy
# 92.0 92.0
# Heart healthy
# 92.0 92.0
# Heart healthy
# 93.0 92.0
# Heart healthy
# 93.0 92.0
# Heart healthy
# 93.0 92.0
# Heart healthy
# 93.0 92.0
# Heart healthy
# 93.0 92.0
# Heart healthy
# 92.0 92.0
# Heart healthy
# 92.0 92.0
# Heart healthy
# 92.0 92.0
# Heart healthy
# 91.0 92.0
# Heart healthy
# 91.0 92.0
# Heart healthy
# 90.0 93.0
# Heart healthy
# 90.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 90.0 93.0
# Heart healthy
# 90.0 93.0
# Heart healthy
# 90.0 93.0
# Heart healthy
# 90.0 93.0
# Heart healthy
# 90.0 93.0
# Heart healthy
# 90.0 93.0
# Heart healthy
# 90.0 93.0
# Heart healthy
# 89.0 94.0
# Heart healthy
# 89.0 94.0
# Heart healthy
# 89.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 88.0 93.0
# Heart healthy
# 87.0 93.0
# Heart healthy
# 87.0 93.0
# Heart healthy
# 87.0 93.0
# Heart healthy
# 87.0 93.0
# Heart healthy
# 87.0 93.0
# Heart healthy
# 86.0 93.0
# Heart healthy
# 86.0 93.0
# Heart healthy
# 86.0 93.0
# Heart healthy
# 86.0 93.0
# Heart healthy
# 86.0 93.0
# Heart healthy
# 86.0 93.0
# Heart healthy
# 86.0 93.0
# Heart healthy
# 85.0 93.0
# Heart healthy
# 85.0 93.0
# Heart healthy
# 85.0 93.0
# Heart healthy
# 84.0 93.0
# Heart healthy
# 84.0 93.0
# Heart healthy
# 84.0 93.0
# Heart healthy
# 84.0 93.0
# Heart healthy
# 84.0 93.0
# Heart healthy
# 84.0 93.0
# Heart healthy
# 83.0 93.0
# Heart healthy
# 83.0 93.0
# Heart healthy
# 83.0 93.0
# Heart healthy
# 83.0 93.0
# Heart healthy
# 83.0 93.0
# Heart healthy
# 83.0 93.0
# Heart healthy
# 83.0 93.0
# Heart healthy
# 83.0 94.0
# Heart healthy
# 83.0 94.0
# Heart healthy
# 83.0 94.0
# Heart healthy
# 84.0 94.0
# Heart healthy
# 84.0 94.0
# Heart healthy
# 84.0 94.0
# Heart healthy
# 84.0 94.0
# Heart healthy
# 85.0 94.0
# Heart healthy
# 85.0 94.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 100.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 97.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# Heart healthy
# 98.0 99.0
# ...
# 90.0 99.0
# Heart healthy
# 90.0 99.0
# Heart healthy
# 90.0 99.0
# Heart healthy
# 90.0 99.0
# Heart healthy
# 90.0 99.0
# Heart healthy
# 90.0 99.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 92.0 99.0
# Heart healthy
# 92.0 99.0
# Heart healthy
# 92.0 99.0
# Heart healthy
# 92.0 99.0
# Heart healthy
# 92.0 99.0
# Heart healthy
# 92.0 99.0
# Heart healthy
# 92.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 91.0 99.0
# Heart healthy
# 92.0 99.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 99.0
# Heart healthy
# 89.0 99.0
# Heart healthy
# 89.0 99.0
# Heart healthy
# 89.0 99.0
# Heart healthy
# 89.0 99.0
# Heart healthy
# 89.0 99.0
# Heart healthy
# 90.0 99.0
# Heart healthy
# 90.0 99.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 93.0 98.0
# Heart healthy
# 93.0 98.0
# Heart healthy
# 93.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 92.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 91.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 90.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 89.0 98.0
# Heart healthy
# 88.0 98.0
# Heart healthy
# 88.0 98.0
# Heart healthy
# 88.0 98.0
# Heart healthy
# 88.0 98.0
# Heart healthy
# 87.0 98.0
# Heart healthy
# 87.0 98.0
# Heart healthy
# 87.0 98.0
# Heart healthy
# 87.0 98.0
# Heart healthy
# 87.0 98.0
# Heart healthy
# 87.0 98.0
# Heart healthy
# 87.0 98.0
# Heart healthy
# 87.0 98.0
# Heart healthy
# 87.0 98.0
# Heart healthy
# 88.0 98.0
# Heart healthy
# 88.0 98.0
# Heart healthy
# 88.0 98.0
# Heart healthy
# 88.0 98.0
# Heart healthy
# 88.0 98.0
# Heart healthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 113.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 114.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 115.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 116.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
# 117.0
# Heart unhealthy
#         PULSE   SpO2   HEALTHY HEART
# 0        93.0   97.0               1
# 1        93.0   97.0               1
# 2        93.0   97.0               1
# 3        93.0   97.0               1
# 4        93.0   97.0               1
# ...       ...    ...             ...
# 24526   116.0   93.0               0
# 24527   116.0   93.0               0
# 24528   117.0   93.0               0
# 24529   117.0   93.0               0
# 24530   117.0   93.0               0
#
# [24403 rows x 3 columns]

# %% [markdown]
# Distribution of healthy and unhealthy heart

# %%
# bar graph
plt.title('Data distribution between pulse and oxygen level saturation data') 
target_counts = clean_data[' HEALTHY HEART'].value_counts()
x = clean_data[' HEALTHY HEART']
plt.bar(target_counts.index, target_counts.values)
plt.xticks(target_counts.index, ['0', '1']) 
plt.show()

# %% [markdown]
# Removing skewness and kurtosis

# %%
selected_features = [' PULSE', ' SpO2']

# Calculate the skewness and kurtosis of the original data
original_skewness = data_no_outliers[selected_features].skew()
original_kurtosis = data_no_outliers[selected_features].kurtosis()

# Apply Box-Cox transformation to selected features
transformed_features = pd.DataFrame()
for feature in selected_features:
    transformed_feature, _ = boxcox(data_no_outliers[feature])
    transformed_features[feature] = transformed_feature


# Calculate the skewness and kurtosis of the transformed data

transformed_skewness = transformed_features.skew()
transformed_kurtosis = transformed_features.kurtosis()
transformed_sqrt = np.sqrt(transformed_features)


print("Original Skewness:")
print(original_skewness)
print("\nOriginal Kurtosis:")
print(original_kurtosis)
print("\nTransformed Skewness:")
print(transformed_skewness)
print("\nTransformed Kurtosis:")
print(transformed_kurtosis)
print("\nTransformed Square root:")
print(transformed_sqrt)
# Out:
# Original Skewness:
#  PULSE   -0.082976
#  SpO2    -1.069732
# dtype: float64
#
# Original Kurtosis:
#  PULSE   -0.150687
#  SpO2     0.981620
# dtype: float64
#
# Transformed Skewness:
#  PULSE   -0.013346
#  SpO2    -0.152939
# dtype: float64
#
# Transformed Kurtosis:
#  PULSE   -0.217002
#  SpO2    -0.919877
# dtype: float64
#
# Transformed Square root:
#          PULSE          SpO2
# 0    11.794750  7.913923e+11
# 1    11.865684  7.913923e+11
# 2    11.865684  8.439152e+11
# 3    11.723474  7.913923e+11
# 4    11.651852  7.913923e+11
# ..         ...           ...
# 478  13.349267  6.499968e+11
# 479  13.413572  6.499968e+11
# 480  13.413572  6.945510e+11
# 481  13.349267  6.945510e+11
# 482  13.413572  6.078694e+11
#
# [483 rows x 2 columns]

# %%
plt.title('Removed Skewness and Kurtosis in "PULSE"') 
x = transformed_features[" PULSE"]
plt.hist(x)
plt.show() 

plt.title('Removed Skewness and Kurtosis in "SpO2"') 
x = transformed_features[" SpO2"]
plt.hist(x)
plt.show()

# %% [markdown]
# Normalize a dataset  using MinandMaxSCaler

# %%
scaler = MinMaxScaler()

selected_features = [' PULSE', ' SpO2']
# Apply Min-Max scaling to selected features
clean_data[selected_features] = scaler.fit_transform(clean_data[selected_features])
# Out:
# C:\Users\jessl\AppData\Local\Temp\ipykernel_22300\2224201635.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data[selected_features] = scaler.fit_transform(clean_data[selected_features])

# %%
plt.title('Data distribution for "Peaks"') 
x = clean_data[" PULSE"]
plt.hist(x)
plt.show() 

plt.title('Data distribution for "Spo2"') 
x = clean_data[" SpO2"]
plt.hist(x)
plt.show()

# %%
x1 = clean_data[" SpO2"]
x2 = clean_data[" PULSE"]
y = clean_data[" HEALTHY HEART"]
c = ['r' if heart_condition== 1 else 'b' for heart_condition in clean_data[" HEALTHY HEART"]]

plt.scatter(x1[y==0], x2[y==0], s=3, c='r')
plt.scatter(x1[y==1], x2[y==1], s=3, c='b')
plt.title('Data for both healthy and unhealthy heart')
plt.xlabel('Oxygen level SpO2')
plt.ylabel('Pulse rate')
# Out:
# Text(0, 0.5, 'Pulse rate')

# %%
import matplotlib.pyplot as plt

# Assuming you have two features `x1` and `x2` and a list of y-indices
x1 = clean_data[" SpO2"]
x2 = clean_data[" PULSE"]
y = clean_data[" HEALTHY HEART"]

x1 = np.array(x1)
x2 = np.array(x2)
y = np.array(y)

# Filter the features based on the target class
class_0_x1 = x1[y == 0]
class_0_x2 = x2[y == 0]
class_1_x1 = x1[y == 1]
class_1_x2 = x2[y == 1]

# Generate the y-indices
y_class_1_indices = range(len(class_1_x2))  # Assuming x1 and x2 have the same length

# Plot the features against the y-indices
plt.plot(y_class_1_indices, class_1_x1, label='SPO2')
plt.plot(y_class_1_indices, class_1_x2, label='PULSE')

# Add labels and title
plt.xlabel('index of rows in the dataset')
plt.ylabel('Spo2 and pulse')
plt.title('SPo2 and pulse for healthy heart')

# Add legend
plt.legend()

# Display the plot
plt.show()


y_class_0_indices = range(len(class_0_x2))  # Assuming x1 and x2 have the same length

# Plot the features against the y-indices
plt.plot(y_class_0_indices, class_0_x1, label='SPO2')
plt.plot(y_class_0_indices, class_0_x2, label='PULSE')

# Add labels and title
plt.xlabel('index of rows in the dataset')
plt.ylabel('Spo2 and pulse')
plt.title('SPo2 and pulse for unhealthy heart')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# Adding Target column

# %% [markdown]
# Training and testing dataset in SVM model

# %%
training_dataset = pd.read_csv('Training_heart.csv')

kf=KFold(n_splits=5)

smote = SMOTE()


# features that is not the target label
X = training_dataset.drop(' HEALTHY HEART', axis=1)
y = training_dataset.drop([' PULSE', ' SpO2'], axis=1)

y = np.reshape(y, (-1, 1))

X_train_resampled, y_train_resampled = smote.fit_resample(X, y)

# partitioning data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.36, shuffle=True, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.20, random_state=42)

X_train, y_train = smote.fit_resample(X_train, y_train)

positive_values = np.count_nonzero(y_test ==  1)

# Create and train the One-Class SVM model
model = SVC(kernel='poly', C=0.1, gamma = 1.00) 
model.fit(X_train, y_train )

y_val_pred = model.predict(X_val)

scores = cross_val_score(model, X, y, cv=kf)

val_accuracy = accuracy_score(y_val, y_val_pred)
print("Validation Accuracy: ", val_accuracy)

# Make predictions on the test set
y_test_pred = model.predict(X_test)


# Compute evaluation metrics
positive_percentage = positive_values/ len(y_test)
precision = precision_score(y_test, y_test_pred)
recall = recall_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)
roc_auc = roc_auc_score(y_test, y_test_pred)
auprc = average_precision_score(y_test, y_test_pred)
accuracy = accuracy_score(y_test, y_test_pred)


# Print the evaluation scores
'''
precision = precision_score(y_val, y_test_pred)
recall = recall_score(y_val, y_test_pred)'''

print ("Positive percentage:", positive_percentage)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)  
print("Accuracy ", scores.mean())
print("ROC AUC", roc_auc)
print("AUPRC:", auprc)

# %% [markdown]
# Evaluation of the model

# %%
# save the model 
filename = 'Heart_attack_monitor svm.sav'
joblib.dump(model, filename)
# Out:
# ['Heart_attack_monitor svm.sav']

# %% [markdown]
# Testing the SVM modle performance

# %%
# Load a model
svm_model = joblib.load('Heart_attack_monitor.sav')

val_dataset = pd.read_csv('Validate_heart.csv')
x_val = val_dataset.drop('Normal heart', axis=1)

y_val = val_dataset['Normal heart']  # Replace 'target_column' with the actual column name

# Apply the model to the validation data

y_pred = svm_model.predict(x_val)



positive_percentage = (y_val).sum() / len(y_val)
#precision, recall, thresholds = precision_recall_curve(y_val, y_pred)


# Compute evaluation metrics
f1 = f1_score(y_val, y_pred)

roc_auc = roc_auc_score(y_val, y_pred)

# Print the evaluation scores

outlier_count = (y_val == -1).sum()

precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)

print ("Positive percentage:", positive_percentage)
print("Outlier count:", outlier_count)
print("Precision:", precision)
print("Recall:", recall)
print("Threshold:", thresholds)
print("F1-score:", f1)  
print("ROC AUC", roc_auc)
#print("Accuracy ", scores.mean())

# Calculate AUPRC
auprc = average_precision_score(y_val, y_pred)
print("AUPRC:", auprc)
# Out:
# Positive percentage: 0.9599679743795037
# Outlier count: 500
# Precision: 0.9927382217499114
# Recall: 0.9158496732026143
# Threshold: [0 1]
# F1-score: 0.9527451980282169
# ROC AUC 0.793924836601307
# AUPRC: 0.9916649487436235
